# %%
import pandas as pd
import numpy as np

# %%
df_karan60 = pd.read_csv('karan_60.csv')
df_karan60.isna().sum()
# Out:
# acc_x        0
# acc_y        0
# acc_z        0
# I0           0
# I1           0
# I2           0
# I3           0
# time(sec)    0
# dtype: int64

# %%
df_karan90 = pd.read_csv('karan_90.csv')
df_karan120 = pd.read_csv('karan_120.csv')
df_karan90l = pd.read_csv('karan_90_left.csv')
df_karan90r = pd.read_csv('karan_90_right.csv')
df_karan90.isna().sum()
# Out:
# acc_x        0
# acc_y        0
# acc_z        0
# I0           0
# I1           0
# I2           0
# I3           0
# time(sec)    0
# dtype: int64

# %%
df_pranav60 = pd.read_csv('pranav_60.csv')
df_pranav90 = pd.read_csv('pranav_90.csv')
df_pranav120 = pd.read_csv('pranav_120.csv')
df_pranav90l = pd.read_csv('pranav_90_left.csv')
df_pranav90r = pd.read_csv('pranav_90_right.csv')
df_pranav60.isna().sum()
# Out:
# acc_x        0
# acc_y        0
# acc_z        0
# I0           0
# I1           0
# I2           0
# I3           0
# time(sec)    0
# dtype: int64

# %%
df_vidhu60 = pd.read_csv('vidhu_60.csv')
df_vidhu90 = pd.read_csv('vidhu_90.csv')
df_vidhu120 = pd.read_csv('vidhu_120.csv')
df_vidhu90l = pd.read_csv('vidhu_90_left.csv')
df_vidhu90r = pd.read_csv('vidhu_90_right.csv')
df_vidhu90r.isna().sum()
# Out:
# acc_x        0
# acc_y        0
# acc_z        0
# I0           0
# I1           0
# I2           0
# I3           0
# time(sec)    0
# dtype: int64

# %%
df_yogesh60 = pd.read_csv('yogesh_60.csv')
df_yogesh90 = pd.read_csv('yogesh_90.csv')
df_yogesh120 = pd.read_csv('yogesh_120.csv')
df_yogesh90l = pd.read_csv('yogesh_90_left.csv')
df_yogesh90r = pd.read_csv('yogesh_90_right.csv')
df_yogesh120.head()
# Out:
#    acc_x  acc_y  acc_z  I0  I1  I2  I3  time(sec)
# 0  -4.51  -2.08  -7.45  13  13  15  89        0.0
# 1  -4.86  -1.92  -7.49  13  14  14  88        0.2
# 2  -4.94  -1.69  -7.57  12  11  12  80        0.4
# 3  -4.94  -1.57  -7.53  12  12  13  84        0.6
# 4  -4.98  -1.45  -7.57  12  12  14  82        0.8

# %%
df_60 = pd.concat([df_karan60, df_pranav60, df_vidhu60, df_yogesh60], ignore_index=True)
df_60.head()
# Out:
#    acc_x  acc_y  acc_z  I0  I1  I2  I3  time(sec)
# 0   8.00  -3.73   6.16  19  24  19  56        0.0
# 1   7.92  -3.88   6.16  19  23  19  55        0.2
# 2   8.00  -3.88   6.08  17  20  17  51        0.4
# 3   7.92  -4.20   5.84  15  17  15  44        0.6
# 4   7.81  -4.00   6.04  14  17  14  44        0.8

# %%
df_pranav60.head()
# Out:
#    acc_x  acc_y  acc_z  I0  I1  I2  I3  time(sec)
# 0   8.04  -6.20   0.00   0   2   0   0        0.0
# 1   8.04  -6.32   0.12   0   2   0   0        0.2
# 2   8.04  -6.32   0.20   0   2   0   0        0.4
# 3   8.00  -6.43   0.20   0   2   0   0        0.6
# 4   8.00  -6.24   0.20   0   2   0   0        0.8

# %%
df_60['I3']=0
df_60.head()
# Out:
#    acc_x  acc_y  acc_z  I0  I1  I2  I3  time(sec)
# 0   8.00  -3.73   6.16  19  24  19   0        0.0
# 1   7.92  -3.88   6.16  19  23  19   0        0.2
# 2   8.00  -3.88   6.08  17  20  17   0        0.4
# 3   7.92  -4.20   5.84  15  17  15   0        0.6
# 4   7.81  -4.00   6.04  14  17  14   0        0.8

# %%
df_60['pos']=1
df_60.head()
# Out:
#    acc_x  acc_y  acc_z  I0  I1  I2  I3  time(sec)  pos
# 0   8.00  -3.73   6.16  19  24  19   0        0.0    1
# 1   7.92  -3.88   6.16  19  23  19   0        0.2    1
# 2   8.00  -3.88   6.08  17  20  17   0        0.4    1
# 3   7.92  -4.20   5.84  15  17  15   0        0.6    1
# 4   7.81  -4.00   6.04  14  17  14   0        0.8    1

# %%
df_90 = pd.concat([df_karan90, df_pranav90, df_vidhu90, df_yogesh90], ignore_index=True)
df_90.head()
# Out:
#    acc_x  acc_y  acc_z  I0  I1  I2  I3  time(sec)
# 0   8.00  -5.77   3.73  38  38  38  78        0.0
# 1   8.04  -5.84   3.73  39  39  39  78        0.2
# 2   7.96  -5.73   3.57  39  39  38  79        0.4
# 3   8.04  -5.73   3.57  39  39  38  79        0.6
# 4   7.92  -5.96   3.57  40  41  39  81        0.8

# %%
df_90['pos']=2
df_90.head()
# Out:
#    acc_x  acc_y  acc_z  I0  I1  I2  I3  time(sec)  pos
# 0   8.00  -5.77   3.73  38  38  38  78        0.0    2
# 1   8.04  -5.84   3.73  39  39  39  78        0.2    2
# 2   7.96  -5.73   3.57  39  39  38  79        0.4    2
# 3   8.04  -5.73   3.57  39  39  38  79        0.6    2
# 4   7.92  -5.96   3.57  40  41  39  81        0.8    2

# %%
df_120 = pd.concat([df_karan120, df_pranav120, df_vidhu120, df_yogesh120], ignore_index=True)
df_120.head()
# Out:
#    acc_x  acc_y  acc_z  I0  I1  I2  I3  time(sec)
# 0   8.36  -5.37   3.30  21  21  21  62        0.0
# 1   8.39  -5.45   3.26  21  21  21  61        0.2
# 2   8.36  -5.41   3.37  21  21  21  61        0.4
# 3   8.32  -5.33   3.37  20  20  20  61        0.6
# 4   8.36  -5.37   3.49  21  21  21  63        0.8

# %%
df_120['pos']=3
df_120.head()
# Out:
#    acc_x  acc_y  acc_z  I0  I1  I2  I3  time(sec)  pos
# 0   8.36  -5.37   3.30  21  21  21  62        0.0    3
# 1   8.39  -5.45   3.26  21  21  21  61        0.2    3
# 2   8.36  -5.41   3.37  21  21  21  61        0.4    3
# 3   8.32  -5.33   3.37  20  20  20  61        0.6    3
# 4   8.36  -5.37   3.49  21  21  21  63        0.8    3

# %%
df_90l = pd.concat([df_karan90l, df_pranav90l, df_vidhu90l, df_yogesh90l], ignore_index=True)
df_90l.head()
# Out:
#    acc_x  acc_y  acc_z  I0  I1  I2  I3  time(sec)
# 0   7.26  -6.83   3.61   0   1   0   0        0.0
# 1   7.14  -6.79   3.53   0   1   0   0        0.2
# 2   7.18  -6.83   3.37   0   1   0   0        0.4
# 3   7.22  -6.86   3.37   0   1   0   2        0.6
# 4   7.18  -6.79   3.30   0   1   0   2        0.8

# %%
df_90l['pos']=4
df_90l.head()
# Out:
#    acc_x  acc_y  acc_z  I0  I1  I2  I3  time(sec)  pos
# 0   7.26  -6.83   3.61   0   1   0   0        0.0    4
# 1   7.14  -6.79   3.53   0   1   0   0        0.2    4
# 2   7.18  -6.83   3.37   0   1   0   0        0.4    4
# 3   7.22  -6.86   3.37   0   1   0   2        0.6    4
# 4   7.18  -6.79   3.30   0   1   0   2        0.8    4

# %%
df_90r = pd.concat([df_karan90r, df_pranav90r, df_vidhu90r, df_yogesh90r], ignore_index=True)
df_90r.head()
# Out:
#    acc_x  acc_y  acc_z  I0  I1  I2  I3  time(sec)
# 0   7.34  -6.71   3.45  34  35  34  79        0.0
# 1   7.41  -6.75   3.49  33  34  33  77        0.2
# 2   7.41  -6.67   3.57  32  33  32  75        0.4
# 3   7.41  -6.67   3.57  32  33  32  74        0.6
# 4   7.37  -6.67   3.45  33  34  33  79        0.8

# %%
df_90r['pos']=5
df_90r.head()
# Out:
#    acc_x  acc_y  acc_z  I0  I1  I2  I3  time(sec)  pos
# 0   7.34  -6.71   3.45  34  35  34  79        0.0    5
# 1   7.41  -6.75   3.49  33  34  33  77        0.2    5
# 2   7.41  -6.67   3.57  32  33  32  75        0.4    5
# 3   7.41  -6.67   3.57  32  33  32  74        0.6    5
# 4   7.37  -6.67   3.45  33  34  33  79        0.8    5

# %%
df_final_pos = pd.concat([df_60, df_90, df_120, df_90l, df_90r], ignore_index=True)
# df_final_pos.shape

# %%
df_final_pos.head()
# Out:
#    acc_x  acc_y  acc_z  I0  I1  I2  I3  time(sec)  pos
# 0   8.00  -3.73   6.16  19  24  19   0        0.0    1
# 1   7.92  -3.88   6.16  19  23  19   0        0.2    1
# 2   8.00  -3.88   6.08  17  20  17   0        0.4    1
# 3   7.92  -4.20   5.84  15  17  15   0        0.6    1
# 4   7.81  -4.00   6.04  14  17  14   0        0.8    1

# %%
df_final_pos.isna().sum()
# Out:
# acc_x        0
# acc_y        0
# acc_z        0
# I0           0
# I1           0
# I2           0
# I3           0
# time(sec)    0
# pos          0
# dtype: int64

# %%
# df_final_pos.drop(columns=["pos","time(sec)","acc_x","acc_y","acc_z"],inplace=True)

# %%
df_final_pos.head()

# %%
# Angle.head()

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models,callbacks
from sklearn.model_selection import train_test_split
# Out:
# WARNING:tensorflow:From C:\Users\yashg\anaconda3\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# test_size = 0.2
# X_train, X_test, y_train, y_test = train_test_split(df_final_pos, Angle, test_size=test_size, random_state=42)
# X_test.shape

# %%
from keras.models import Sequential
from keras.utils import to_categorical
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import precision_score, recall_score, f1_score

# Assuming your DataFrame is named df and has columns "sensor1", "sensor2", "sensor3", "sensor4", and "posture"
# You should replace these with your actual column names

# Preprocess the data
X = df_final_pos[['I0', 'I1', 'I2', 'I3']].values
y = df_final_pos['pos'].values

label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)
y_one_hot = to_categorical(y_encoded)
num_classes = len(label_encoder.classes_)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y_one_hot, test_size=0.2, random_state=42)

# Reshape the input data for Conv1D
X_train_reshaped = np.expand_dims(X_train, axis=-1)
X_test_reshaped = np.expand_dims(X_test, axis=-1)

# Build the CNN model
model = Sequential()
model.add(Conv1D(filters=16, kernel_size=3, activation='relu', input_shape=(4, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
history = model.fit(X_train_reshaped, y_train, epochs=20, batch_size=32, validation_data=(X_test_reshaped, y_test))

# Evaluate the model
loss, accuracy = model.evaluate(X_test_reshaped, y_test)
print(f'Test Loss: {loss:.4f}')
print(f'Test Accuracy: {accuracy:.4f}')
y_pred_cnn_prob = model.predict(X_test_reshaped)
y_pred_cnn = y_pred_cnn_prob.argmax(axis=1)
y_test_labels = y_test.argmax(axis=1)

cnn_precision = precision_score(y_test_labels, y_pred_cnn, average='weighted')
cnn_recall = recall_score(y_test_labels, y_pred_cnn, average='weighted')
cnn_f1 = f1_score(y_test_labels, y_pred_cnn, average='weighted')

print(f'CNN Test Precision: {cnn_precision:.4f}')
print(f'CNN Test Recall: {cnn_recall:.4f}')
print(f'CNN Test F1 Score: {cnn_f1:.4f}')

# # Encode the labels
# label_encoder = LabelEncoder()
# y = label_encoder.fit_transform(y)
# Out:
# Epoch 1/20
# 330/330 [==============================] - 1s 3ms/step - loss: 1.7384 - accuracy: 0.5447 - val_loss: 0.6433 - val_accuracy: 0.7246
# Epoch 2/20
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6517 - accuracy: 0.7408 - val_loss: 0.4862 - val_accuracy: 0.8149
# Epoch 3/20
# 330/330 [==============================] - 1s 2ms/step - loss: 0.4873 - accuracy: 0.8168 - val_loss: 0.3721 - val_accuracy: 0.8892
# Epoch 4/20
# 330/330 [==============================] - 1s 2ms/step - loss: 0.3643 - accuracy: 0.8712 - val_loss: 0.3044 - val_accuracy: 0.9253
# Epoch 5/20
# 330/330 [==============================] - 1s 2ms/step - loss: 0.3016 - accuracy: 0.8959 - val_loss: 0.2521 - val_accuracy: 0.9476
# Epoch 6/20
# 330/330 [==============================] - 1s 2ms/step - loss: 0.2581 - accuracy: 0.9071 - val_loss: 0.2267 - val_accuracy: 0.9530
# Epoch 7/20
# ...

# %%
import matplotlib.pyplot as plt

# Assuming history is already defined and contains 'accuracy' and 'val_accuracy'

plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

# Customizing the legend
plt.legend(loc='upper right', fontsize='10', title_fontsize='13', frameon=True, shadow=True, bbox_to_anchor=(1.40, 1.05))

plt.show()

# %%
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
# plt.xlim(0,20)
# plt.title('Training and Validation Loss')
plt.legend(loc='upper right', fontsize='10', title_fontsize='13', frameon=True, shadow=True, bbox_to_anchor=(1.35, 1.05))
plt.show()

# %%
ann_model = Sequential()
ann_model.add(Dense(64, activation='relu', input_shape=(4,)))
ann_model.add(Dense(64, activation='relu'))
ann_model.add(Dense(num_classes, activation='softmax'))

# Compile the ANN model
ann_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the ANN model
history_ann = ann_model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_test, y_test))

# Evaluate the ANN model
loss_ann, accuracy_ann = ann_model.evaluate(X_test, y_test)
print(f'Test Loss: {loss_ann:.4f}')
print(f'Test Accuracy: {accuracy_ann:.4f}')

y_pred_ann_prob = ann_model.predict(X_test)
y_pred_ann = y_pred_ann_prob.argmax(axis=1)
y_test_labels = y_test.argmax(axis=1)

ann_precision = precision_score(y_test_labels, y_pred_ann, average='weighted')
ann_recall = recall_score(y_test_labels, y_pred_ann, average='weighted')
ann_f1 = f1_score(y_test_labels, y_pred_ann, average='weighted')

print(f'ANN Test Precision: {ann_precision:.4f}')
print(f'ANN Test Recall: {ann_recall:.4f}')
print(f'ANN Test F1 Score: {ann_f1:.4f}')

# Plot training and validation accuracy
plt.plot(history_ann.history['accuracy'], label='Training Accuracy')
plt.plot(history_ann.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy (ANN)')
plt.legend()
plt.show()
# Out:
# Epoch 1/10
# 330/330 [==============================] - 1s 2ms/step - loss: 0.9295 - accuracy: 0.6894 - val_loss: 0.4764 - val_accuracy: 0.8376
# Epoch 2/10
# 330/330 [==============================] - 1s 2ms/step - loss: 0.4093 - accuracy: 0.8524 - val_loss: 0.3022 - val_accuracy: 0.9074
# Epoch 3/10
# 330/330 [==============================] - 1s 2ms/step - loss: 0.2648 - accuracy: 0.9087 - val_loss: 0.2276 - val_accuracy: 0.9374
# Epoch 4/10
# 330/330 [==============================] - 1s 2ms/step - loss: 0.2081 - accuracy: 0.9209 - val_loss: 0.4163 - val_accuracy: 0.8448
# Epoch 5/10
# 330/330 [==============================] - 1s 2ms/step - loss: 0.1862 - accuracy: 0.9302 - val_loss: 0.2087 - val_accuracy: 0.9291
# Epoch 6/10
# 330/330 [==============================] - 1s 2ms/step - loss: 0.1466 - accuracy: 0.9436 - val_loss: 0.1798 - val_accuracy: 0.9393
# Epoch 7/10
# ...

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# Preprocess the data
X = df_final_pos[['I0', 'I1', 'I2', 'I3']].values
y = df_final_pos['pos'].values

label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# Train the SVM model
svm_model = SVC(kernel='linear')  # You can change the kernel as needed
svm_model.fit(X_train, y_train)

# Predict and evaluate the model
y_pred_svm = svm_model.predict(X_test)
# svm_accuracy = accuracy_score(y_test, y_pred_svm)
# print(f'SVM Test Accuracy: {svm_accuracy:.4f}')
svm_accuracy = accuracy_score(y_test, y_pred_svm)
svm_precision = precision_score(y_test, y_pred_svm, average='weighted')
svm_recall = recall_score(y_test, y_pred_svm, average='weighted')
svm_f1 = f1_score(y_test, y_pred_svm, average='weighted')

print(f'SVM Test Accuracy: {svm_accuracy:.4f}')
print(f'SVM Test Precision: {svm_precision:.4f}')
print(f'SVM Test Recall: {svm_recall:.4f}')
print(f'SVM Test F1 Score: {svm_f1:.4f}')
# Out:
# SVM Test Accuracy: 0.8407
# SVM Test Precision: 0.8447
# SVM Test Recall: 0.8407
# SVM Test F1 Score: 0.8380

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score

# Preprocess the data
X = df_final_pos[['I0', 'I1', 'I2', 'I3']].values
y = df_final_pos['pos'].values

label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# Train the Gradient Boosting model
gbm_model = GradientBoostingClassifier(n_estimators=10, random_state=42)
gbm_model.fit(X_train, y_train)

# Predict and evaluate the model
y_pred_gbm = gbm_model.predict(X_test)
gbm_accuracy = accuracy_score(y_test, y_pred_gbm)
gbm_precision = precision_score(y_test, y_pred_gbm, average='weighted')
gbm_recall = recall_score(y_test, y_pred_gbm, average='weighted')
gbm_f1 = f1_score(y_test, y_pred_gbm, average='weighted')

print(f'Gradient Boosting Test Accuracy: {gbm_accuracy:.4f}')
print(f'Gradient Boosting Test Precision: {gbm_precision:.4f}')
print(f'Gradient Boosting Test Recall: {gbm_recall:.4f}')
print(f'Gradient Boosting Test F1 Score: {gbm_f1:.4f}')
# print(f'Gradient Boosting Test Accuracy: {gbm_accuracy:.4f}')
# Out:
# Gradient Boosting Test Accuracy: 0.9302
# Gradient Boosting Test Precision: 0.9307
# Gradient Boosting Test Recall: 0.9302
# Gradient Boosting Test F1 Score: 0.9286

# %%
import xgboost as xgb
from sklearn.metrics import accuracy_score

# Preprocess the data
X = df_final_pos[['I0', 'I1', 'I2', 'I3']].values
y = df_final_pos['pos'].values

label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# Train the XGBoost model
xgb_model = xgb.XGBClassifier(n_estimators=10, random_state=42)
xgb_model.fit(X_train, y_train)

# Predict and evaluate the model
y_pred_xgb = xgb_model.predict(X_test)
# xgb_accuracy = accuracy_score(y_test, y_pred_xgb)
xgb_accuracy = accuracy_score(y_test, y_pred_xgb)
xgb_precision = precision_score(y_test, y_pred_xgb, average='weighted')
xgb_recall = recall_score(y_test, y_pred_xgb, average='weighted')
xgb_f1 = f1_score(y_test, y_pred_xgb, average='weighted')

print(f'XGBoost Test Accuracy: {xgb_accuracy:.4f}')
print(f'XGBoost Test Precision: {xgb_precision:.4f}')
print(f'XGBoost Test Recall: {xgb_recall:.4f}')
print(f'XGBoost Test F1 Score: {xgb_f1:.4f}')
# Out:
# XGBoost Test Accuracy: 0.9719
# XGBoost Test Precision: 0.9721
# XGBoost Test Recall: 0.9719
# XGBoost Test F1 Score: 0.9719
